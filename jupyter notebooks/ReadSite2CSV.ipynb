# %%
##### IMPORTS #####
from coastcamDBfuncs import *
from coastcamDB_yaml_funcs import *

# %%
#table name 
siteID = '7654321'
#folder to save csv to
path = '/home/jovyan/CoastCamDB/csv/'

# %%
#Need a csv file of parameters to connect to the database
#file will have: host, port, dbname, user, password
csv_file = "/home/jovyan/CoastCamDB/db_access.csv"
conn = DBConnectCSV(csv_file)

# %%
#save csv. function returns Pandas dataframe of the SQL query
result = site2csv(siteID, path, conn)
print(result)
# Out:
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /srv/conda/envs/pangeo/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Saved csv files to /home/jovyan/CoastCamDB/csv//sites/7654321/tables/
# [  seq       id               name   lat   lon  elev zDatumNote  TZoffset  \
#    16  7654321  Example Site, USA  10.0 -10.0   0.0  sea level      -240
#
#   tideSource waveSource  ...  DenominatorOfFlatteningRatio GeoID  \
#      9759394      12345  ...                          12.0  exID
#
#                AltitudeDatumName  AltitudeDistanceUnits  ContactOrganization  \
#   North American Vertical Datum                  meters                 USGS
#
#   ContactPerson      ContactEmail ContactVoiceTelephone  \
#        John Doe  johndoe@usgs.gov           12345678910
#
#                             ContactAddress   timestamp
#   600 4th St S, Saint Petersburg, FL 33701  1657652756
#
# [1 rows x 30 columns],   seq       id  shortName                  name   siteID      timeIN  \
#    24  7654321  examplexx  example site station  7654321  1567015200
#    27  8120313       None              bingbong  7654321           0
#    37  csvtest    csvTest     test the csv code  7654321  1000000000
#    25  elpmaxx   another1                        7654321           0
#    26   xtestx       None                        7654321           0
#
#      timeOUT     timestamp stationid
#   1629119895  1.657653e+09   EXSTATX
#            0           NaN
#   1111111111  1.000000e+09
#            0           NaN
#            0           NaN            ,  seq       id stationID syncsToID lensSN cameraSN  filters orientation  \
#    6  1234567   7654321      none  12345    12345  fisheye           n
#    9  example   7654321      none  12345    54321  fisheye           n
#   10    fffff   elpmaxx                     54321     None
#   19             xtestx                               None
#
#  cameraNumber      timeIN  ...     y     z polarizerFlag  \
#             1  1654538400  ...   2.2   3.3             0
#             2  1650000000  ...   2.2   3.3             0
#             2  1654538400  ...  None  None          None
#             0           0  ...  None  None          None
#
#                             K           kc   timestamp polAngle modelID  \
#   [[1 2 3], [4 5 6], [7 8 9]]  [1 2 3 4 5]  1658517499    999.0   XXXXX
#   [[1 2 3], [4 5 6], [7 8 9]]  [1 2 3 4 5]  1658763812    999.0   XXXXX
#                          None         None        None     None   XXXXX
#                          None         None        None     None    None
#
#  lensmodelID  li_IP
#        XXXXX  XXXXX
#        XXXXX  XXXXX
#        XXXXX  XXXXX
#         None   None
#
# [4 rows x 22 columns],   seq     id  make      model  size color   timestamp
# 0   3  XXXXX  FLIR  blackflyS  0.25     1  1657652756,   seq     id     make     model       f aperture autoIris   timestamp
# 0   3  XXXXX  Fujinon  HF9HA-1S  0.0125   0.0125        1  1657652756,   seq     id             make             model               name width  \
# 0   3  XXXXX  ip make example  ip model example  human readable ip   500
#
#   height pixelWidth pixelHeight   timestamp
# 0    500        1.0         1.0  1657652756  ,   seq     id         name   siteID      timeIN     timeOUT    x    y    z  \
#    32  YXXXY  example gcp  7654321  1657652756  1657652756  1.0  2.0  3.0
#
#    timestamp
#   1657652756  ,   seq  tilt azimuth   fov  roll                 imagePath    whenDone  \
# 0  16  None    None  None  None                      None           0
# 0  15   2.0     1.0  10.0   3.0  /home/images/example.jpg  1660160038
#
#     whenValid   err version solvedVars      user tiltCI azimuthCI rollCI  \
# 0           0  None    None                        None      None   None
# 0  1660160038  0.05     1.2    tarfxyz  John Doe    0.5       0.5    0.5
#
#                                                    m   timestamp cameraID
# 0                                               None        None  1234567
# 0  [ 2.1029e+02 -7.6537e+02 -1.9403e+02  8.0914e+...  1660160038  example  ]
